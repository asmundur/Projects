# %% [markdown]
# <a href="https://colab.research.google.com/github/asmundur/Projects/blob/master/Copy_of_deep_learning_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#code based on kernel https://www.kaggle.com/hrmello/flow-from-dataframe-a-memory-friendly-approach


from googleapiclient.discovery import build
import io, os, cv2, csv
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mplimg
from matplotlib.pyplot import imshow
from skimage.io import imread

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from keras import layers
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D, Reshape, Permute
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D, Concatenate
from keras.layers import LSTM
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import regularizers

import keras.backend as K
from keras.models import Sequential

import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)

# %%
auth.authenticate_user()
drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'kaggle.json'", fields="files(id)").execute()
kaggle_api_key = results.get('files', [])
filename = "/content/.kaggle/kaggle.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)
request = drive_service.files().get_media(fileId=kaggle_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)



# !pip install kaggle
# Out:
# Download 100%.
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.1.1)
# Requirement already satisfied: urllib3<1.23.0,>=1.15 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2018.11.29)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: Unidecode>=0.04.16 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.0.23)

# %%
# if not os.path.exists('./data'):
# !cp /content/.kaggle/kaggle.json /root/.kaggle/kaggle.json
if (not os.path.exists('./train')) and (not os.path.exists('./test')):
  # !kaggle competitions download -c humpback-whale-identification
  # !unzip -q train.zip -d train
  # !ls train | wc -l
  # !unzip -q test.zip -d test
  # !ls test | wc -l

# %%
# #!ls -a /root/.kaggle

# #!cp /content/.kaggle/kaggle.json /root/.kaggle/kaggle.json
# if not os.path.exists('./train'):
#   !unzip -q train.zip -d train

# !ls train | wc -l

# if not os.path.exists('./test'):
#   !unzip -q test.zip -d test

# !ls test | wc -l

# %% [markdown]
# # Data preparation

# %%
N = 5
train_df = pd.read_csv("./train.csv")
is_not_new_whale = train_df['Id'] != 'new_whale'
# get ids with more than X images:
# 
# has_more_than_N_images = train_df['Id'] in ids
# print(has_more_than_N_images)
train_df = train_df[is_not_new_whale]
# is_2002 =  gapminder['year']==2002

ids = train_df.Id.value_counts()[train_df.Id.value_counts()<=N].index
id_list = ids.tolist()
for identity in id_list:
  temp = train_df['Id'] != identity
  train_df = train_df[temp]
  
# train_df = train_df[has_more_than_N_images]

# print(id_list)
# print(train_df.head())

img_path = './train/'

#get the first 5 whale images
images = [(whale_img, whale_label) for (whale_img, whale_label) in zip(train_df.Image[:5], train_df.Id[:5])]

fig, m_axs = plt.subplots(1, len(images), figsize = (20, 10))
#show the images and label them
for ii, c_ax in enumerate(m_axs):
    c_ax.imshow(imread(os.path.join(img_path,images[ii][0])))
    c_ax.set_title(images[ii][1])

#how many photos of each whail    
train_df.Id.value_counts()
# Out:
# w_23a388d    73
# w_9b5109b    65
# w_9c506f6    62
# w_0369a5c    61
# w_700ebb4    57
# w_3de579a    54
# w_564a34b    51
# w_fd3e556    50
# w_88e4537    49
# w_2b069ba    48
# w_d405854    47
# w_f0fe284    45
# w_789c969    45
# w_5e8e218    40
# w_343f088    40
# w_778e474    40
# w_5a2634c    37
# w_60ce6fc    37
# w_a9304b9    37
# w_6822dbc    36
# w_af367c3    35
# w_1ca9ab1    34
# w_f765256    34
# w_17b0d3a    33
# w_d72771c    32
# w_8c25681    31
# w_6cda039    31
# w_08630fd    31
# w_04003e9    30
# w_fd6a3ad    30
#              ..
# w_8f4d879     6
# w_0f466a5     6
# w_8cfabed     6
# w_ae32f8b     6
# w_714f89f     6
# w_fc10c15     6
# w_4fadedd     6
# w_12aae3e     6
# w_244e953     6
# w_8936c44     6
# w_9697236     6
# w_8d0a2a2     6
# w_04d4568     6
# w_88065f2     6
# w_611d18b     6
# w_3ff114c     6
# w_3fe5d56     6
# w_fe15413     6
# w_e25b062     6
# w_de657c1     6
# w_8cad422     6
# w_a780b2d     6
# w_32838db     6
# w_5116e7e     6
# w_37e61c2     6
# w_96c6613     6
# w_85d9229     6
# w_b99f945     6
# w_9eaef8f     6
# w_3da0eae     6
# Name: Id, Length: 633, dtype: int64

# %%
# Make test directory

from distutils.dir_util import copy_tree

#create directories
if not os.path.exists('./test_folder'):
  os.mkdir('./test_folder')
  os.mkdir('./test_folder/test_images')

# copy subdirectory example
fromDirectory = "./test"
toDirectory = "test_folder/test_images"

copy_tree(fromDirectory, toDirectory, verbose=0)
# Out:
# ['test_folder/test_images/4b317dd80.jpg',
#  'test_folder/test_images/18c1e0336.jpg',
#  'test_folder/test_images/bdcfe13dd.jpg',
#  'test_folder/test_images/6801584ad.jpg',
#  'test_folder/test_images/706a514e6.jpg',
#  'test_folder/test_images/622ab5446.jpg',
#  'test_folder/test_images/1171cf967.jpg',
#  'test_folder/test_images/737c68b02.jpg',
#  'test_folder/test_images/b4da6e3a3.jpg',
#  'test_folder/test_images/4d685a22c.jpg',
#  'test_folder/test_images/a9ec154aa.jpg',
#  'test_folder/test_images/8d64a3f56.jpg',
#  'test_folder/test_images/9e7e79ed7.jpg',
#  'test_folder/test_images/7d139e2fb.jpg',
#  'test_folder/test_images/7e1e483c5.jpg',
#  'test_folder/test_images/85deba351.jpg',
#  'test_folder/test_images/3bcf68475.jpg',
#  'test_folder/test_images/f71943862.jpg',
#  'test_folder/test_images/bb53d003f.jpg',
#  'test_folder/test_images/ee4c43621.jpg',
#  'test_folder/test_images/b246ec122.jpg',
#  'test_folder/test_images/64feaaa64.jpg',
#  'test_folder/test_images/356412267.jpg',
#  'test_folder/test_images/e515a13db.jpg',
#  'test_folder/test_images/afb62053a.jpg',
#  'test_folder/test_images/e76a76e80.jpg',
#  'test_folder/test_images/4cbdbb886.jpg',
#  'test_folder/test_images/28282c21d.jpg',
#  'test_folder/test_images/cb5ed9e92.jpg',
#  'test_folder/test_images/b2198c611.jpg',
#  'test_folder/test_images/8206ef622.jpg',
#  'test_folder/test_images/d63e52c0f.jpg',
#  'test_folder/test_images/d9291eb54.jpg',
#  'test_folder/test_images/65fff5e87.jpg',
#  'test_folder/test_images/04a763f43.jpg',
#  'test_folder/test_images/d34322077.jpg',
#  'test_folder/test_images/45f8c9aad.jpg',
#  'test_folder/test_images/cc70e7bd7.jpg',
#  'test_folder/test_images/72905e678.jpg',
#  'test_folder/test_images/09ae7a1c4.jpg',
#  'test_folder/test_images/4cb865beb.jpg',
#  'test_folder/test_images/c51cc0cb0.jpg',
#  'test_folder/test_images/aa8b44ee0.jpg',
#  'test_folder/test_images/2b2f869a0.jpg',
#  'test_folder/test_images/1e75d9abc.jpg',
#  'test_folder/test_images/091a88443.jpg',
#  'test_folder/test_images/29716b682.jpg',
#  'test_folder/test_images/ae55ff96f.jpg',
#  'test_folder/test_images/0a9f76baa.jpg',
#  'test_folder/test_images/f7452424a.jpg',
#  'test_folder/test_images/1729983ba.jpg',
#  'test_folder/test_images/f87792ce3.jpg',
#  'test_folder/test_images/fee0dd873.jpg',
#  'test_folder/test_images/276513d28.jpg',
#  'test_folder/test_images/5c1dc4bc6.jpg',
#  'test_folder/test_images/144bd190c.jpg',
#  'test_folder/test_images/d03f497ef.jpg',
#  'test_folder/test_images/63a33efa4.jpg',
#  'test_folder/test_images/a6a279938.jpg',
#  'test_folder/test_images/236a7f36e.jpg',
#  'test_folder/test_images/8f6fc3ba5.jpg',
#  'test_folder/test_images/2ef0d7089.jpg',
#  'test_folder/test_images/3ac350828.jpg',
#  'test_folder/test_images/86a174149.jpg',
#  'test_folder/test_images/e16fe82e5.jpg',
#  'test_folder/test_images/6bdcf9f09.jpg',
#  'test_folder/test_images/72d77d558.jpg',
#  'test_folder/test_images/0cf642c94.jpg',
#  'test_folder/test_images/af47c5bda.jpg',
#  'test_folder/test_images/8f3bd4dfb.jpg',
#  'test_folder/test_images/5fa416c01.jpg',
#  'test_folder/test_images/38475674e.jpg',
#  'test_folder/test_images/c3ee2fa18.jpg',
#  'test_folder/test_images/60c9a3a3e.jpg',
#  'test_folder/test_images/5408e3340.jpg',
#  'test_folder/test_images/8ab31a146.jpg',
#  'test_folder/test_images/27a153404.jpg',
#  'test_folder/test_images/33b4d0699.jpg',
#  'test_folder/test_images/0cc139a82.jpg',
#  'test_folder/test_images/2f199ca48.jpg',
#  'test_folder/test_images/178098115.jpg',
#  'test_folder/test_images/05f560c71.jpg',
#  'test_folder/test_images/0c2522fbd.jpg',
#  'test_folder/test_images/f7663e305.jpg',
#  'test_folder/test_images/68e34d8e3.jpg',
#  'test_folder/test_images/ee154380e.jpg',
#  'test_folder/test_images/9810d93bc.jpg',
#  'test_folder/test_images/511ec9e80.jpg',
#  'test_folder/test_images/3f40d5bb1.jpg',
#  'test_folder/test_images/94b92952b.jpg',
#  'test_folder/test_images/bf085c508.jpg',
#  'test_folder/test_images/2eac926e3.jpg',
#  'test_folder/test_images/a260c0a4c.jpg',
#  'test_folder/test_images/f0adfd02e.jpg',
#  'test_folder/test_images/034b5f550.jpg',
#  'test_folder/test_images/a5de374ec.jpg',
#  'test_folder/test_images/6c1c1d173.jpg',
#  'test_folder/test_images/c5afe6f79.jpg',
#  'test_folder/test_images/ac7350385.jpg',
#  'test_folder/test_images/9c9cdcb78.jpg',
#  'test_folder/test_images/d8d8f945f.jpg',
#  'test_folder/test_images/57a187f7c.jpg',
#  'test_folder/test_images/73f3cc616.jpg',
#  'test_folder/test_images/a3719d098.jpg',
#  'test_folder/test_images/02ab81ee7.jpg',
#  'test_folder/test_images/332a57fe7.jpg',
#  'test_folder/test_images/8809a5aa0.jpg',
#  'test_folder/test_images/cc34d57c5.jpg',
#  'test_folder/test_images/4ae49bc07.jpg',
#  'test_folder/test_images/5b31ae7bf.jpg',
#  'test_folder/test_images/87b11af7d.jpg',
#  'test_folder/test_images/a9b4bef82.jpg',
#  'test_folder/test_images/657be368a.jpg',
#  'test_folder/test_images/395a9e8fc.jpg',
#  'test_folder/test_images/fbcba6ed2.jpg',
#  'test_folder/test_images/5d14c33af.jpg',
#  'test_folder/test_images/2d9f0c8b8.jpg',
#  'test_folder/test_images/e782e4ae2.jpg',
#  'test_folder/test_images/866c45338.jpg',
#  'test_folder/test_images/53b7b1ff9.jpg',
#  'test_folder/test_images/c104744b9.jpg',
#  'test_folder/test_images/31d6d48e1.jpg',
#  'test_folder/test_images/2f0f07af1.jpg',
#  'test_folder/test_images/2654ca2c1.jpg',
#  'test_folder/test_images/2cb0363d0.jpg',
#  'test_folder/test_images/02b063a20.jpg',
#  'test_folder/test_images/6b3d78e6b.jpg',
#  'test_folder/test_images/bef453e65.jpg',
#  'test_folder/test_images/6c5fa352d.jpg',
#  'test_folder/test_images/0ffda96bd.jpg',
#  'test_folder/test_images/cf19274ba.jpg',
#  'test_folder/test_images/c2790e7c9.jpg',
#  'test_folder/test_images/8119c7305.jpg',
#  'test_folder/test_images/714572bbc.jpg',
#  'test_folder/test_images/882c07680.jpg',
#  'test_folder/test_images/b69f4fd6a.jpg',
#  'test_folder/test_images/2bf0aa7e8.jpg',
#  'test_folder/test_images/d610e5a10.jpg',
#  'test_folder/test_images/4132bade6.jpg',
#  'test_folder/test_images/ac37a321f.jpg',
#  'test_folder/test_images/2442a5353.jpg',
#  'test_folder/test_images/3b92598c9.jpg',
#  'test_folder/test_images/93614bab6.jpg',
#  'test_folder/test_images/8fb1dba5c.jpg',
#  'test_folder/test_images/5526526fc.jpg',
#  'test_folder/test_images/c17786f3f.jpg',
#  'test_folder/test_images/74d2eac26.jpg',
#  'test_folder/test_images/774f9b712.jpg',
#  'test_folder/test_images/cae2f13bc.jpg',
#  'test_folder/test_images/0fde4f5b5.jpg',
#  'test_folder/test_images/8a0ef6827.jpg',
#  'test_folder/test_images/f20d4315e.jpg',
#  'test_folder/test_images/277508f3b.jpg',
#  'test_folder/test_images/70a52a46a.jpg',
#  'test_folder/test_images/5519006ff.jpg',
#  'test_folder/test_images/ee5027205.jpg',
#  'test_folder/test_images/c414e98a3.jpg',
#  'test_folder/test_images/814ebc18e.jpg',
#  'test_folder/test_images/eb34af4ac.jpg',
#  'test_folder/test_images/f94271a9f.jpg',
#  'test_folder/test_images/cb1d43123.jpg',
#  'test_folder/test_images/26222e02e.jpg',
#  'test_folder/test_images/438ff3dc5.jpg',
#  'test_folder/test_images/c768e7e93.jpg',
#  'test_folder/test_images/fb7d098a5.jpg',
#  'test_folder/test_images/d08c78fa8.jpg',
#  'test_folder/test_images/eeb9b3cdc.jpg',
#  'test_folder/test_images/bb6c3f5d5.jpg',
#  'test_folder/test_images/0e5538c86.jpg',
#  'test_folder/test_images/d598d6858.jpg',
#  'test_folder/test_images/09232fe8c.jpg',
#  'test_folder/test_images/2e6401fb0.jpg',
#  'test_folder/test_images/11e15e585.jpg',
#  'test_folder/test_images/9d16c82ad.jpg',
#  'test_folder/test_images/5a5dfde16.jpg',
#  'test_folder/test_images/c4100a53c.jpg',
#  'test_folder/test_images/20ea355d3.jpg',
#  'test_folder/test_images/6b6953818.jpg',
#  'test_folder/test_images/270e405fb.jpg',
#  'test_folder/test_images/87aaa993e.jpg',
#  'test_folder/test_images/210c30aef.jpg',
#  'test_folder/test_images/a716d3ef1.jpg',
#  'test_folder/test_images/9ddc37f53.jpg',
#  'test_folder/test_images/2c9de8518.jpg',
#  'test_folder/test_images/a11d5558d.jpg',
#  'test_folder/test_images/3b82fe211.jpg',
#  'test_folder/test_images/749bcebb5.jpg',
#  'test_folder/test_images/f517bcc21.jpg',
#  'test_folder/test_images/461b560c0.jpg',
#  'test_folder/test_images/5e4ad7f18.jpg',
#  'test_folder/test_images/c1a9a1a6b.jpg',
#  'test_folder/test_images/31093fbfa.jpg',
#  'test_folder/test_images/262f5cb0c.jpg',
#  'test_folder/test_images/702c9eb7e.jpg',
#  'test_folder/test_images/bb4c09c33.jpg',
#  'test_folder/test_images/fcd4ad309.jpg',
#  'test_folder/test_images/f3a8dc7a8.jpg',
#  'test_folder/test_images/580722429.jpg',
#  'test_folder/test_images/771fc7aaf.jpg',
#  'test_folder/test_images/9ef6ee19d.jpg',
#  'test_folder/test_images/4734beb51.jpg',
#  'test_folder/test_images/4fab2efae.jpg',
#  'test_folder/test_images/9025f2c3c.jpg',
#  'test_folder/test_images/515a71b9e.jpg',
#  'test_folder/test_images/975316ce9.jpg',
#  'test_folder/test_images/61503d083.jpg',
#  'test_folder/test_images/9ce78e146.jpg',
#  'test_folder/test_images/e07d1534e.jpg',
#  'test_folder/test_images/178bc715f.jpg',
#  'test_folder/test_images/1ef017dff.jpg',
#  'test_folder/test_images/73286e810.jpg',
#  'test_folder/test_images/c0607c316.jpg',
#  'test_folder/test_images/d8d7e07d8.jpg',
#  'test_folder/test_images/65ee8c179.jpg',
#  'test_folder/test_images/c79e99b47.jpg',
#  'test_folder/test_images/1e862d802.jpg',
#  'test_folder/test_images/83ba3a456.jpg',
#  'test_folder/test_images/64fa02e44.jpg',
#  'test_folder/test_images/93589894e.jpg',
#  'test_folder/test_images/150024216.jpg',
#  'test_folder/test_images/1bd566d62.jpg',
#  'test_folder/test_images/d513a83dc.jpg',
#  'test_folder/test_images/c9343b725.jpg',
#  'test_folder/test_images/4d35014a3.jpg',
#  'test_folder/test_images/0cb4662dd.jpg',
#  'test_folder/test_images/a5658e8fb.jpg',
#  'test_folder/test_images/6b37a5e9e.jpg',
#  'test_folder/test_images/7917b34f8.jpg',
#  'test_folder/test_images/81fc4ae42.jpg',
#  'test_folder/test_images/8e2a9088d.jpg',
#  'test_folder/test_images/54dc270b5.jpg',
#  'test_folder/test_images/98c8ef2d9.jpg',
#  'test_folder/test_images/08fea2581.jpg',
#  'test_folder/test_images/704b9ea0b.jpg',
#  'test_folder/test_images/2bece1295.jpg',
#  'test_folder/test_images/0b9b6b8ef.jpg',
#  'test_folder/test_images/6f9442470.jpg',
#  'test_folder/test_images/2fefb335d.jpg',
#  'test_folder/test_images/9afbfd6ea.jpg',
#  'test_folder/test_images/1bebce356.jpg',
#  'test_folder/test_images/5dc82cfe5.jpg',
#  'test_folder/test_images/a40e8ccd3.jpg',
#  'test_folder/test_images/60fcac50e.jpg',
#  'test_folder/test_images/a478fbecc.jpg',
#  'test_folder/test_images/363c92f2a.jpg',
#  'test_folder/test_images/ffffc6980.jpg',
#  'test_folder/test_images/c84b9f02b.jpg',
#  'test_folder/test_images/746a1d151.jpg',
#  'test_folder/test_images/3e0e3ec53.jpg',
#  'test_folder/test_images/7747e1c5d.jpg',
#  'test_folder/test_images/173fbc026.jpg',
#  'test_folder/test_images/7ea531ea0.jpg',
#  'test_folder/test_images/6f8462bb2.jpg',
#  'test_folder/test_images/aea9d41f2.jpg',
#  'test_folder/test_images/be22d0a88.jpg',
#  'test_folder/test_images/c67c1e7c8.jpg',
#  'test_folder/test_images/156cd5898.jpg',
#  'test_folder/test_images/f9a5defeb.jpg',
#  'test_folder/test_images/22a357189.jpg',
#  'test_folder/test_images/7bf401859.jpg',
#  'test_folder/test_images/702c05d67.jpg',
#  'test_folder/test_images/b6f713a31.jpg',
#  'test_folder/test_images/f2a022cca.jpg',
#  'test_folder/test_images/5fc9a9630.jpg',
#  'test_folder/test_images/f50529c53.jpg',
#  'test_folder/test_images/8f5d2204a.jpg',
#  'test_folder/test_images/2cf93fddf.jpg',
#  'test_folder/test_images/e67e2f713.jpg',
#  'test_folder/test_images/4302c9c2b.jpg',
#  'test_folder/test_images/1174922af.jpg',
#  'test_folder/test_images/ed49a67b8.jpg',
#  'test_folder/test_images/7dac9d96c.jpg',
#  'test_folder/test_images/83033395f.jpg',
#  'test_folder/test_images/3c4055f42.jpg',
#  'test_folder/test_images/83dcc971e.jpg',
#  'test_folder/test_images/63d094dad.jpg',
#  'test_folder/test_images/9af7769b3.jpg',
#  'test_folder/test_images/b15d828f4.jpg',
#  'test_folder/test_images/7bda7e3c9.jpg',
#  'test_folder/test_images/f76b3e796.jpg',
#  'test_folder/test_images/7f29643d0.jpg',
#  'test_folder/test_images/f9fdac10d.jpg',
#  'test_folder/test_images/7198af93e.jpg',
#  'test_folder/test_images/0bfd71606.jpg',
#  'test_folder/test_images/f81b83c5b.jpg',
#  'test_folder/test_images/dcb501be7.jpg',
#  'test_folder/test_images/a610ba97f.jpg',
#  'test_folder/test_images/325b218cd.jpg',
#  'test_folder/test_images/e6b21c6c5.jpg',
#  'test_folder/test_images/8392ed906.jpg',
#  'test_folder/test_images/8cd8d759c.jpg',
#  'test_folder/test_images/cbc080fa3.jpg',
#  'test_folder/test_images/61efc78a7.jpg',
#  'test_folder/test_images/31a53d6e5.jpg',
#  'test_folder/test_images/6e21dba65.jpg',
#  'test_folder/test_images/bba5883d7.jpg',
#  'test_folder/test_images/fa990e098.jpg',
#  'test_folder/test_images/e7d685096.jpg',
#  'test_folder/test_images/cfeae6723.jpg',
#  'test_folder/test_images/614f959ec.jpg',
#  'test_folder/test_images/a923990c0.jpg',
#  'test_folder/test_images/144a969b9.jpg',
#  'test_folder/test_images/5b73f2f2b.jpg',
#  'test_folder/test_images/c6e00efc5.jpg',
#  'test_folder/test_images/27c53ea05.jpg',
#  'test_folder/test_images/e7084c222.jpg',
#  'test_folder/test_images/d60fb6598.jpg',
#  'test_folder/test_images/1001c4ea8.jpg',
#  'test_folder/test_images/d65b3dcbb.jpg',
#  'test_folder/test_images/be9004d7b.jpg',
#  'test_folder/test_images/79071aaed.jpg',
#  'test_folder/test_images/1a72251b0.jpg',
#  'test_folder/test_images/0ff98563c.jpg',
#  'test_folder/test_images/1c976a4cb.jpg',
#  'test_folder/test_images/47daf0d83.jpg',
#  'test_folder/test_images/1bdd2f1c8.jpg',
#  'test_folder/test_images/3e4fb23a1.jpg',
#  'test_folder/test_images/15dd3f9ef.jpg',
#  'test_folder/test_images/adbb8a9d6.jpg',
#  'test_folder/test_images/93a523c92.jpg',
#  'test_folder/test_images/fbd12a21b.jpg',
#  'test_folder/test_images/be8551936.jpg',
#  'test_folder/test_images/7cdcb2249.jpg',
#  'test_folder/test_images/878a9df5d.jpg',
#  'test_folder/test_images/64eeed60b.jpg',
#  'test_folder/test_images/6c13370b9.jpg',
#  'test_folder/test_images/dbff2f5fc.jpg',
#  'test_folder/test_images/1ecb5556c.jpg',
#  'test_folder/test_images/a558a4774.jpg',
#  'test_folder/test_images/93e7cf309.jpg',
#  'test_folder/test_images/8be681b07.jpg',
#  'test_folder/test_images/efc9c5469.jpg',
#  'test_folder/test_images/d4366acf6.jpg',
#  'test_folder/test_images/07910d9c9.jpg',
#  'test_folder/test_images/002f52f0c.jpg',
#  'test_folder/test_images/5b0b37f12.jpg',
#  'test_folder/test_images/f4613a2f8.jpg',
#  'test_folder/test_images/0f3c1f2ca.jpg',
#  'test_folder/test_images/c7eaa8027.jpg',
#  'test_folder/test_images/b76c39822.jpg',
#  'test_folder/test_images/f1b73b091.jpg',
#  'test_folder/test_images/072faed30.jpg',
#  'test_folder/test_images/b31a9ddb8.jpg',
#  'test_folder/test_images/aab1dc60b.jpg',
#  'test_folder/test_images/2dd067330.jpg',
#  'test_folder/test_images/1fbd2683f.jpg',
#  'test_folder/test_images/03f6f8101.jpg',
#  'test_folder/test_images/bc6259f19.jpg',
#  'test_folder/test_images/0da9f950f.jpg',
#  'test_folder/test_images/596691ccc.jpg',
#  'test_folder/test_images/e5e19804e.jpg',
#  'test_folder/test_images/a7784e824.jpg',
#  'test_folder/test_images/482da4f35.jpg',
#  'test_folder/test_images/9d7ffbc76.jpg',
#  'test_folder/test_images/b0e1e0d35.jpg',
#  'test_folder/test_images/251bdcbb6.jpg',
#  'test_folder/test_images/11d369040.jpg',
#  'test_folder/test_images/3351f4f65.jpg',
#  'test_folder/test_images/3b4397d09.jpg',
#  'test_folder/test_images/39b0d1ea7.jpg',
#  'test_folder/test_images/27cf4220b.jpg',
#  'test_folder/test_images/5ffc2d300.jpg',
#  'test_folder/test_images/f481df0c4.jpg',
#  'test_folder/test_images/9a5f3d89e.jpg',
#  'test_folder/test_images/507079706.jpg',
#  'test_folder/test_images/46b9a8b9f.jpg',
#  'test_folder/test_images/45b408a2e.jpg',
#  'test_folder/test_images/f261b4f79.jpg',
#  'test_folder/test_images/c117b794d.jpg',
#  'test_folder/test_images/883f79d02.jpg',
#  'test_folder/test_images/c29f0a0ac.jpg',
#  'test_folder/test_images/b15f078db.jpg',
#  'test_folder/test_images/036ebab77.jpg',
#  'test_folder/test_images/0ed1078f8.jpg',
#  'test_folder/test_images/81150357b.jpg',
#  'test_folder/test_images/db8f7a660.jpg',
#  'test_folder/test_images/3ab4766a0.jpg',
#  'test_folder/test_images/2e1b94101.jpg',
#  'test_folder/test_images/ab3df6741.jpg',
#  'test_folder/test_images/8bad77a8d.jpg',
#  'test_folder/test_images/8f12dffcf.jpg',
#  'test_folder/test_images/b72eec424.jpg',
#  'test_folder/test_images/4dcb78207.jpg',
#  'test_folder/test_images/063752d10.jpg',
#  'test_folder/test_images/f6ec838db.jpg',
#  'test_folder/test_images/e36384185.jpg',
#  'test_folder/test_images/40087d09a.jpg',
#  'test_folder/test_images/92f5dbd49.jpg',
#  'test_folder/test_images/778ee8164.jpg',
#  'test_folder/test_images/3e5db9e5b.jpg',
#  'test_folder/test_images/9bcb5006f.jpg',
#  'test_folder/test_images/4582d20d0.jpg',
#  'test_folder/test_images/ca0add85f.jpg',
#  'test_folder/test_images/61d1dde9b.jpg',
#  'test_folder/test_images/744276ef3.jpg',
#  'test_folder/test_images/1fc48c1d1.jpg',
#  'test_folder/test_images/d928f2ded.jpg',
#  'test_folder/test_images/00744bd58.jpg',
#  'test_folder/test_images/360df7609.jpg',
#  'test_folder/test_images/7fd5f9fc1.jpg',
#  'test_folder/test_images/b3919404e.jpg',
#  'test_folder/test_images/c1048b3f4.jpg',
#  'test_folder/test_images/f338d9c16.jpg',
#  'test_folder/test_images/a30eed8c8.jpg',
#  'test_folder/test_images/e64042019.jpg',
#  'test_folder/test_images/780338f93.jpg',
#  'test_folder/test_images/7883e847c.jpg',
#  'test_folder/test_images/b015ae8e2.jpg',
#  'test_folder/test_images/4614dfe6a.jpg',
#  'test_folder/test_images/f2db0fb11.jpg',
#  'test_folder/test_images/9ea71a302.jpg',
#  'test_folder/test_images/ea6befa40.jpg',
#  'test_folder/test_images/ff4db73bd.jpg',
#  'test_folder/test_images/1361968f4.jpg',
#  'test_folder/test_images/c516d13b7.jpg',
#  'test_folder/test_images/89da38524.jpg',
#  'test_folder/test_images/a91b1f245.jpg',
#  'test_folder/test_images/576822ffe.jpg',
#  'test_folder/test_images/889e02582.jpg',
#  'test_folder/test_images/0a8c32aa2.jpg',
#  'test_folder/test_images/648d3981f.jpg',
#  'test_folder/test_images/bd9f115ad.jpg',
#  'test_folder/test_images/4d31ac4d6.jpg',
#  'test_folder/test_images/660049e53.jpg',
#  'test_folder/test_images/4421a2118.jpg',
#  'test_folder/test_images/0eb876427.jpg',
#  'test_folder/test_images/b1bb43706.jpg',
#  'test_folder/test_images/07f496bc6.jpg',
#  'test_folder/test_images/6e6ff3b74.jpg',
#  'test_folder/test_images/df2147539.jpg',
#  'test_folder/test_images/3766465af.jpg',
#  'test_folder/test_images/d831e87de.jpg',
#  'test_folder/test_images/b62b652a3.jpg',
#  'test_folder/test_images/9f6f4d8ab.jpg',
#  'test_folder/test_images/da79c68e7.jpg',
#  'test_folder/test_images/5f4289116.jpg',
#  'test_folder/test_images/eaadafa78.jpg',
#  'test_folder/test_images/253a10e3d.jpg',
#  'test_folder/test_images/62381ef6a.jpg',
#  'test_folder/test_images/0c490c283.jpg',
#  'test_folder/test_images/a679f847d.jpg',
#  'test_folder/test_images/3e1c1364a.jpg',
#  'test_folder/test_images/70eaed7a1.jpg',
#  'test_folder/test_images/a97fb90d7.jpg',
#  'test_folder/test_images/d347a68fc.jpg',
#  'test_folder/test_images/33c7c1326.jpg',
#  'test_folder/test_images/ed0031e82.jpg',
#  'test_folder/test_images/5eb592b49.jpg',
#  'test_folder/test_images/c46a83c43.jpg',
#  'test_folder/test_images/f2c2ced53.jpg',
#  'test_folder/test_images/18876f5a7.jpg',
#  'test_folder/test_images/7b635e279.jpg',
#  'test_folder/test_images/0982ee2f3.jpg',
#  'test_folder/test_images/1292ea088.jpg',
#  'test_folder/test_images/607692cda.jpg',
#  'test_folder/test_images/d5e7d3caf.jpg',
#  'test_folder/test_images/40f14bb62.jpg',
#  'test_folder/test_images/e23615e20.jpg',
#  'test_folder/test_images/ee2a8f607.jpg',
#  'test_folder/test_images/8e09a790d.jpg',
#  'test_folder/test_images/c61b88f6a.jpg',
#  'test_folder/test_images/f9a27c073.jpg',
#  'test_folder/test_images/914f2f86c.jpg',
#  'test_folder/test_images/50e61bb82.jpg',
#  'test_folder/test_images/a6c9db434.jpg',
#  'test_folder/test_images/618f8f91a.jpg',
#  'test_folder/test_images/5bcd04fbe.jpg',
#  'test_folder/test_images/4060168de.jpg',
#  'test_folder/test_images/5120b7b8b.jpg',
#  'test_folder/test_images/a7e2cb2ad.jpg',
#  'test_folder/test_images/49fac9953.jpg',
#  'test_folder/test_images/55ac09c20.jpg',
#  'test_folder/test_images/ef59ca55e.jpg',
#  'test_folder/test_images/3abd3082c.jpg',
#  'test_folder/test_images/49cd8f929.jpg',
#  'test_folder/test_images/13d309a13.jpg',
#  'test_folder/test_images/86faae6a6.jpg',
#  'test_folder/test_images/ba8c64486.jpg',
#  'test_folder/test_images/f57b67033.jpg',
#  'test_folder/test_images/a11a0f304.jpg',
#  'test_folder/test_images/4332a7705.jpg',
#  'test_folder/test_images/fc1817e47.jpg',
#  'test_folder/test_images/6eebb5d97.jpg',
#  'test_folder/test_images/633fd788a.jpg',
#  'test_folder/test_images/4df0f5618.jpg',
#  'test_folder/test_images/247fd8957.jpg',
#  'test_folder/test_images/5065af91a.jpg',
#  'test_folder/test_images/ed65e01b7.jpg',
#  'test_folder/test_images/a7bda31aa.jpg',
#  'test_folder/test_images/2a032bd66.jpg',
#  'test_folder/test_images/1d6701d80.jpg',
#  'test_folder/test_images/e6881ee20.jpg',
#  'test_folder/test_images/e2057aa55.jpg',
#  'test_folder/test_images/52ce11aae.jpg',
#  'test_folder/test_images/e6a20c522.jpg',
#  'test_folder/test_images/83a5aa086.jpg',
#  'test_folder/test_images/83b2a8a76.jpg',
#  'test_folder/test_images/4cc4b8a69.jpg',
#  'test_folder/test_images/23fe8fa38.jpg',
#  'test_folder/test_images/1070f12c3.jpg',
#  'test_folder/test_images/1fb74285e.jpg',
#  'test_folder/test_images/38ce8506f.jpg',
#  'test_folder/test_images/5c178e7af.jpg',
#  'test_folder/test_images/f19a63014.jpg',
#  'test_folder/test_images/9e38c63b1.jpg',
#  'test_folder/test_images/9f7f49faa.jpg',
#  'test_folder/test_images/5202c6c7b.jpg',
#  'test_folder/test_images/e052bff8b.jpg',
#  'test_folder/test_images/b865f6461.jpg',
#  'test_folder/test_images/17002a91a.jpg',
#  'test_folder/test_images/f16a3587b.jpg',
#  'test_folder/test_images/152fd62f7.jpg',
#  'test_folder/test_images/84092b852.jpg',
#  'test_folder/test_images/d31310f97.jpg',
#  'test_folder/test_images/6f01473b9.jpg',
#  'test_folder/test_images/4d56f9a3e.jpg',
#  'test_folder/test_images/1b0954425.jpg',
#  'test_folder/test_images/782caa2b8.jpg',
#  'test_folder/test_images/1afea7c23.jpg',
#  'test_folder/test_images/e1e9ecc6f.jpg',
#  'test_folder/test_images/121392e9a.jpg',
#  'test_folder/test_images/15cf50029.jpg',
#  'test_folder/test_images/5ade0ce80.jpg',
#  'test_folder/test_images/a422c383d.jpg',
#  'test_folder/test_images/e05f2bdef.jpg',
#  'test_folder/test_images/32cdf6b69.jpg',
#  'test_folder/test_images/e90588126.jpg',
#  'test_folder/test_images/244c50b07.jpg',
#  'test_folder/test_images/b82aba32a.jpg',
#  'test_folder/test_images/95bc8b405.jpg',
#  'test_folder/test_images/291e2ce78.jpg',
#  'test_folder/test_images/badcc1376.jpg',
#  'test_folder/test_images/a6e5e476d.jpg',
#  'test_folder/test_images/67cb588bb.jpg',
#  'test_folder/test_images/4a118b84c.jpg',
#  'test_folder/test_images/a743769eb.jpg',
#  'test_folder/test_images/0d185d2df.jpg',
#  'test_folder/test_images/57eb29e16.jpg',
#  'test_folder/test_images/9924ee6b2.jpg',
#  'test_folder/test_images/053951fbe.jpg',
#  'test_folder/test_images/4f4703839.jpg',
#  'test_folder/test_images/19e56cba6.jpg',
#  'test_folder/test_images/5b1dce72b.jpg',
#  'test_folder/test_images/482a7dd9c.jpg',
#  'test_folder/test_images/9f1ebf31e.jpg',
#  'test_folder/test_images/8776b5948.jpg',
#  'test_folder/test_images/9b25c9dce.jpg',
#  'test_folder/test_images/de515c0e4.jpg',
#  'test_folder/test_images/d855dc94b.jpg',
#  'test_folder/test_images/8b6714dd4.jpg',
#  'test_folder/test_images/4671c5038.jpg',
#  'test_folder/test_images/dd962073b.jpg',
#  'test_folder/test_images/16abbece8.jpg',
#  'test_folder/test_images/fddd008a3.jpg',
#  'test_folder/test_images/9b2911931.jpg',
#  'test_folder/test_images/e41c14a90.jpg',
#  'test_folder/test_images/0885f9f70.jpg',
#  'test_folder/test_images/1201e4a8a.jpg',
#  'test_folder/test_images/1a66a8b1b.jpg',
#  'test_folder/test_images/6a57843f3.jpg',
#  'test_folder/test_images/9335f4310.jpg',
#  'test_folder/test_images/ab3b9b4d0.jpg',
#  'test_folder/test_images/0c9dd9352.jpg',
#  'test_folder/test_images/235d3f767.jpg',
#  'test_folder/test_images/c8ebeae7c.jpg',
#  'test_folder/test_images/c320e5e28.jpg',
#  'test_folder/test_images/65130f087.jpg',
#  'test_folder/test_images/543160c9d.jpg',
#  'test_folder/test_images/7626376ac.jpg',
#  'test_folder/test_images/06e8c3191.jpg',
#  'test_folder/test_images/829108d61.jpg',
#  'test_folder/test_images/dce1fd759.jpg',
#  'test_folder/test_images/65a212335.jpg',
#  'test_folder/test_images/002de4d94.jpg',
#  'test_folder/test_images/224ce010a.jpg',
#  'test_folder/test_images/8472b638b.jpg',
#  'test_folder/test_images/139bca777.jpg',
#  'test_folder/test_images/8d4cde07e.jpg',
#  'test_folder/test_images/7e27b8815.jpg',
#  'test_folder/test_images/0ec7b958d.jpg',
#  'test_folder/test_images/74edc0f88.jpg',
#  'test_folder/test_images/0ec0bfe08.jpg',
#  'test_folder/test_images/5f225d380.jpg',
#  'test_folder/test_images/bcc947fe7.jpg',
#  'test_folder/test_images/a1a3d6732.jpg',
#  'test_folder/test_images/7bb7fce17.jpg',
#  'test_folder/test_images/65ee9bbf6.jpg',
#  'test_folder/test_images/71ef8b935.jpg',
#  'test_folder/test_images/292b2b27d.jpg',
#  'test_folder/test_images/cd410d224.jpg',
#  'test_folder/test_images/c1e0c3098.jpg',
#  'test_folder/test_images/afca47dee.jpg',
#  'test_folder/test_images/c13e46298.jpg',
#  'test_folder/test_images/c1f8f9e7f.jpg',
#  'test_folder/test_images/736a568a4.jpg',
#  'test_folder/test_images/981226dff.jpg',
#  'test_folder/test_images/6c206e13b.jpg',
#  'test_folder/test_images/c10aa0ed6.jpg',
#  'test_folder/test_images/524b05dbc.jpg',
#  'test_folder/test_images/9c4605a06.jpg',
#  'test_folder/test_images/232980839.jpg',
#  'test_folder/test_images/7b3a5f118.jpg',
#  'test_folder/test_images/d2c2adbc9.jpg',
#  'test_folder/test_images/3e4d4b012.jpg',
#  'test_folder/test_images/dd036204d.jpg',
#  'test_folder/test_images/e1ab034fc.jpg',
#  'test_folder/test_images/a373fb5b7.jpg',
#  'test_folder/test_images/2c26b4727.jpg',
#  'test_folder/test_images/301209fea.jpg',
#  'test_folder/test_images/bef7a8545.jpg',
#  'test_folder/test_images/5b902a65b.jpg',
#  'test_folder/test_images/5b51146f6.jpg',
#  'test_folder/test_images/7f9182bde.jpg',
#  'test_folder/test_images/dc98417ae.jpg',
#  'test_folder/test_images/3a9aab364.jpg',
#  'test_folder/test_images/582a3e32e.jpg',
#  'test_folder/test_images/00edab267.jpg',
#  'test_folder/test_images/fe27e60b1.jpg',
#  'test_folder/test_images/043f01afd.jpg',
#  'test_folder/test_images/cc5360c6f.jpg',
#  'test_folder/test_images/22bab7681.jpg',
#  'test_folder/test_images/9b993704e.jpg',
#  'test_folder/test_images/ab57627db.jpg',
#  'test_folder/test_images/8b533971f.jpg',
#  'test_folder/test_images/c5d74c91f.jpg',
#  'test_folder/test_images/5649d4769.jpg',
#  'test_folder/test_images/3edd76b8c.jpg',
#  'test_folder/test_images/df3bc6e66.jpg',
#  'test_folder/test_images/0c99493b7.jpg',
#  'test_folder/test_images/5907bfba8.jpg',
#  'test_folder/test_images/724a7c2a9.jpg',
#  'test_folder/test_images/4f4797b3a.jpg',
#  'test_folder/test_images/106b4a3dc.jpg',
#  'test_folder/test_images/d72a65293.jpg',
#  'test_folder/test_images/3f40351b0.jpg',
#  'test_folder/test_images/3953aa075.jpg',
#  'test_folder/test_images/197b703e4.jpg',
#  'test_folder/test_images/41e6a3730.jpg',
#  'test_folder/test_images/810ef0298.jpg',
#  'test_folder/test_images/60838eedc.jpg',
#  'test_folder/test_images/9302aae5a.jpg',
#  'test_folder/test_images/eeb2c13bb.jpg',
#  'test_folder/test_images/7cf3137a7.jpg',
#  'test_folder/test_images/5fd9f7be8.jpg',
#  'test_folder/test_images/b1df06725.jpg',
#  'test_folder/test_images/b3c15a813.jpg',
#  'test_folder/test_images/817e00f66.jpg',
#  'test_folder/test_images/3f9168754.jpg',
#  'test_folder/test_images/3f812be5d.jpg',
#  'test_folder/test_images/76028341e.jpg',
#  'test_folder/test_images/a4059f04e.jpg',
#  'test_folder/test_images/00dc02f06.jpg',
#  'test_folder/test_images/4e1426137.jpg',
#  'test_folder/test_images/2a892eea8.jpg',
#  'test_folder/test_images/10bdd7d09.jpg',
#  'test_folder/test_images/6fb6fbe92.jpg',
#  'test_folder/test_images/f0ebc84c6.jpg',
#  'test_folder/test_images/c0dc8c424.jpg',
#  'test_folder/test_images/ae2a4ae34.jpg',
#  'test_folder/test_images/a07e5d7ed.jpg',
#  'test_folder/test_images/84715ff10.jpg',
#  'test_folder/test_images/60fe2414a.jpg',
#  'test_folder/test_images/581396c4a.jpg',
#  'test_folder/test_images/7669f81d8.jpg',
#  'test_folder/test_images/a365b5321.jpg',
#  'test_folder/test_images/ccb638ee6.jpg',
#  'test_folder/test_images/bc85b9349.jpg',
#  'test_folder/test_images/68681491d.jpg',
#  'test_folder/test_images/c454c5e60.jpg',
#  'test_folder/test_images/1a099d8b8.jpg',
#  'test_folder/test_images/8335d942b.jpg',
#  'test_folder/test_images/ef535e775.jpg',
#  'test_folder/test_images/12108a49b.jpg',
#  'test_folder/test_images/a3bfd8451.jpg',
#  'test_folder/test_images/aa5e9313a.jpg',
#  'test_folder/test_images/8455a7494.jpg',
#  'test_folder/test_images/cb7ecaea4.jpg',
#  'test_folder/test_images/f6aa0fd97.jpg',
#  'test_folder/test_images/865bb5f27.jpg',
#  'test_folder/test_images/5e6cbaf3c.jpg',
#  'test_folder/test_images/5af2d6181.jpg',
#  'test_folder/test_images/1dbc71f0a.jpg',
#  'test_folder/test_images/d4ae47434.jpg',
#  'test_folder/test_images/84e539fe3.jpg',
#  'test_folder/test_images/c63dbc87b.jpg',
#  'test_folder/test_images/3e141f18f.jpg',
#  'test_folder/test_images/f553318b3.jpg',
#  'test_folder/test_images/cec7840be.jpg',
#  'test_folder/test_images/52f683c99.jpg',
#  'test_folder/test_images/e9c1e71d2.jpg',
#  'test_folder/test_images/cd7e932c4.jpg',
#  'test_folder/test_images/acb62c308.jpg',
#  'test_folder/test_images/223d82225.jpg',
#  'test_folder/test_images/6b82ec0ca.jpg',
#  'test_folder/test_images/f479e37c3.jpg',
#  'test_folder/test_images/cf7e23707.jpg',
#  'test_folder/test_images/8f1b66a46.jpg',
#  'test_folder/test_images/d9b319b8c.jpg',
#  'test_folder/test_images/77535177e.jpg',
#  'test_folder/test_images/6a0c72dc1.jpg',
#  'test_folder/test_images/b272cec9b.jpg',
#  'test_folder/test_images/8da6ddac9.jpg',
#  'test_folder/test_images/7b5574b15.jpg',
#  'test_folder/test_images/07c46b13b.jpg',
#  'test_folder/test_images/27ec493c2.jpg',
#  'test_folder/test_images/8534e36e4.jpg',
#  'test_folder/test_images/886b500bc.jpg',
#  'test_folder/test_images/61e9ca42b.jpg',
#  'test_folder/test_images/16fb6303c.jpg',
#  'test_folder/test_images/919af8225.jpg',
#  'test_folder/test_images/36973e99c.jpg',
#  'test_folder/test_images/69a1eb868.jpg',
#  'test_folder/test_images/da2f893bd.jpg',
#  'test_folder/test_images/8900e3f78.jpg',
#  'test_folder/test_images/cf842eacd.jpg',
#  'test_folder/test_images/6e701fb83.jpg',
#  'test_folder/test_images/d58ebf451.jpg',
#  'test_folder/test_images/1832ea593.jpg',
#  'test_folder/test_images/5d776fc45.jpg',
#  'test_folder/test_images/97f72805f.jpg',
#  'test_folder/test_images/1c8d579b1.jpg',
#  'test_folder/test_images/74f798613.jpg',
#  'test_folder/test_images/9ead182d5.jpg',
#  'test_folder/test_images/96b0ab1d9.jpg',
#  'test_folder/test_images/4b98bfaa9.jpg',
#  'test_folder/test_images/d907398f6.jpg',
#  'test_folder/test_images/dc4c39727.jpg',
#  'test_folder/test_images/6cbf7a5a3.jpg',
#  'test_folder/test_images/faef829f5.jpg',
#  'test_folder/test_images/54b911d89.jpg',
#  'test_folder/test_images/1d0297622.jpg',
#  'test_folder/test_images/ae8526935.jpg',
#  'test_folder/test_images/c6f73bf85.jpg',
#  'test_folder/test_images/5108e9014.jpg',
#  'test_folder/test_images/70055f80b.jpg',
#  'test_folder/test_images/ff2b1bd37.jpg',
#  'test_folder/test_images/28363f2d4.jpg',
#  'test_folder/test_images/c93096b85.jpg',
#  'test_folder/test_images/8a18b21df.jpg',
#  'test_folder/test_images/4276cbefd.jpg',
#  'test_folder/test_images/79061808e.jpg',
#  'test_folder/test_images/11a4f47b7.jpg',
#  'test_folder/test_images/ae6b2f936.jpg',
#  'test_folder/test_images/6b86da034.jpg',
#  'test_folder/test_images/964e02b3c.jpg',
#  'test_folder/test_images/5e054ccb1.jpg',
#  'test_folder/test_images/ff09b5efb.jpg',
#  'test_folder/test_images/b4909c744.jpg',
#  'test_folder/test_images/92ee448c0.jpg',
#  'test_folder/test_images/f151e1a6d.jpg',
#  'test_folder/test_images/0ef1395fd.jpg',
#  'test_folder/test_images/64489df49.jpg',
#  'test_folder/test_images/a4db2c0a7.jpg',
#  'test_folder/test_images/8473b9c07.jpg',
#  'test_folder/test_images/c26e92a03.jpg',
#  'test_folder/test_images/8843b117c.jpg',
#  'test_folder/test_images/e6426c0e0.jpg',
#  'test_folder/test_images/f15a5b897.jpg',
#  'test_folder/test_images/65b594cc6.jpg',
#  'test_folder/test_images/b70fa5fe2.jpg',
#  'test_folder/test_images/6d3ad6d76.jpg',
#  'test_folder/test_images/4257fb8cc.jpg',
#  'test_folder/test_images/c0381fc3a.jpg',
#  'test_folder/test_images/cf0431821.jpg',
#  'test_folder/test_images/5985b125a.jpg',
#  'test_folder/test_images/8826ff3a4.jpg',
#  'test_folder/test_images/6c813950a.jpg',
#  'test_folder/test_images/88c230b0e.jpg',
#  'test_folder/test_images/36ac860f2.jpg',
#  'test_folder/test_images/8a68e55e3.jpg',
#  'test_folder/test_images/2278e13e4.jpg',
#  'test_folder/test_images/21bd9ddf4.jpg',
#  'test_folder/test_images/6272dff3b.jpg',
#  'test_folder/test_images/660f0590b.jpg',
#  'test_folder/test_images/9839cf047.jpg',
#  'test_folder/test_images/ba250a21e.jpg',
#  'test_folder/test_images/3bebe67aa.jpg',
#  'test_folder/test_images/dba90a7a0.jpg',
#  'test_folder/test_images/5ed79621a.jpg',
#  'test_folder/test_images/535bf59fa.jpg',
#  'test_folder/test_images/ed3b97209.jpg',
#  'test_folder/test_images/b6a0d16b4.jpg',
#  'test_folder/test_images/11850b2ea.jpg',
#  'test_folder/test_images/5deee355e.jpg',
#  'test_folder/test_images/4e3e001cb.jpg',
#  'test_folder/test_images/9b7f5065e.jpg',
#  'test_folder/test_images/35ea99e30.jpg',
#  'test_folder/test_images/769e6d7e6.jpg',
#  'test_folder/test_images/bec1b14cc.jpg',
#  'test_folder/test_images/6c3279d8d.jpg',
#  'test_folder/test_images/e524eade3.jpg',
#  'test_folder/test_images/4894a5f94.jpg',
#  'test_folder/test_images/11e0bcf3a.jpg',
#  'test_folder/test_images/10437724b.jpg',
#  'test_folder/test_images/817fdbcec.jpg',
#  'test_folder/test_images/5345e8a17.jpg',
#  'test_folder/test_images/efc9b26f5.jpg',
#  'test_folder/test_images/6b05c7b9c.jpg',
#  'test_folder/test_images/2043794e5.jpg',
#  'test_folder/test_images/c27ce139c.jpg',
#  'test_folder/test_images/e1060f178.jpg',
#  'test_folder/test_images/3f11d31d8.jpg',
#  'test_folder/test_images/331c42937.jpg',
#  'test_folder/test_images/ca39c88d4.jpg',
#  'test_folder/test_images/b2e98c229.jpg',
#  'test_folder/test_images/0447d2303.jpg',
#  'test_folder/test_images/a7ed0bdf4.jpg',
#  'test_folder/test_images/0383ee2bb.jpg',
#  'test_folder/test_images/22ef3c6bd.jpg',
#  'test_folder/test_images/81fe37eaf.jpg',
#  'test_folder/test_images/7a424c980.jpg',
#  'test_folder/test_images/9bf5c23f1.jpg',
#  'test_folder/test_images/fba60e84a.jpg',
#  'test_folder/test_images/f8f5e8ee4.jpg',
#  'test_folder/test_images/fa8c43cd0.jpg',
#  'test_folder/test_images/e6d8597ab.jpg',
#  'test_folder/test_images/f6ee1ca42.jpg',
#  'test_folder/test_images/c5638a746.jpg',
#  'test_folder/test_images/82221a701.jpg',
#  'test_folder/test_images/4188acc6e.jpg',
#  'test_folder/test_images/13f36f3d6.jpg',
#  'test_folder/test_images/15209239a.jpg',
#  'test_folder/test_images/d2712bce3.jpg',
#  'test_folder/test_images/dec47e2f5.jpg',
#  'test_folder/test_images/88ab63c4d.jpg',
#  'test_folder/test_images/8995e32d7.jpg',
#  'test_folder/test_images/fb51dc57e.jpg',
#  'test_folder/test_images/7df2168b2.jpg',
#  'test_folder/test_images/91c657859.jpg',
#  'test_folder/test_images/db04b0f37.jpg',
#  'test_folder/test_images/39716aa36.jpg',
#  'test_folder/test_images/62d41a859.jpg',
#  'test_folder/test_images/311cbec8b.jpg',
#  'test_folder/test_images/14e842bf1.jpg',
#  'test_folder/test_images/973c6b0b6.jpg',
#  'test_folder/test_images/f7a8cd22d.jpg',
#  'test_folder/test_images/8544e24b1.jpg',
#  'test_folder/test_images/3d027843a.jpg',
#  'test_folder/test_images/51d76ddc9.jpg',
#  'test_folder/test_images/e76ab8b2c.jpg',
#  'test_folder/test_images/31892c478.jpg',
#  'test_folder/test_images/260808fa5.jpg',
#  'test_folder/test_images/bf0ac4a74.jpg',
#  'test_folder/test_images/176ff5648.jpg',
#  'test_folder/test_images/ff5c4f83c.jpg',
#  'test_folder/test_images/bdc77d7e1.jpg',
#  'test_folder/test_images/c2b249f5b.jpg',
#  'test_folder/test_images/2152f9a67.jpg',
#  'test_folder/test_images/3fc571ba4.jpg',
#  'test_folder/test_images/55cb7488f.jpg',
#  'test_folder/test_images/84d906f35.jpg',
#  'test_folder/test_images/d19bf7ea9.jpg',
#  'test_folder/test_images/2c1a6c05c.jpg',
#  'test_folder/test_images/02626b1c3.jpg',
#  'test_folder/test_images/9f96fee80.jpg',
#  'test_folder/test_images/2af53ac76.jpg',
#  'test_folder/test_images/63f24cb25.jpg',
#  'test_folder/test_images/7b180a857.jpg',
#  'test_folder/test_images/b21ffa413.jpg',
#  'test_folder/test_images/3ab77e041.jpg',
#  'test_folder/test_images/a2292feca.jpg',
#  'test_folder/test_images/71dc4563f.jpg',
#  'test_folder/test_images/5689dd329.jpg',
#  'test_folder/test_images/bb862c684.jpg',
#  'test_folder/test_images/cb5cf19d8.jpg',
#  'test_folder/test_images/178bf6b87.jpg',
#  'test_folder/test_images/3e2d13f38.jpg',
#  'test_folder/test_images/b75883f99.jpg',
#  'test_folder/test_images/c0bce1b53.jpg',
#  'test_folder/test_images/9bf997af9.jpg',
#  'test_folder/test_images/00ca82e74.jpg',
#  'test_folder/test_images/4fede041d.jpg',
#  'test_folder/test_images/42c3ac658.jpg',
#  'test_folder/test_images/9d972ef0a.jpg',
#  'test_folder/test_images/8a9f34d2f.jpg',
#  'test_folder/test_images/88a5f6f7e.jpg',
#  'test_folder/test_images/fbfa6334e.jpg',
#  'test_folder/test_images/2e1ea7050.jpg',
#  'test_folder/test_images/70d6c9e57.jpg',
#  'test_folder/test_images/0edc4f945.jpg',
#  'test_folder/test_images/c4d6a39fb.jpg',
#  'test_folder/test_images/e2a4a7e75.jpg',
#  'test_folder/test_images/8f7d64247.jpg',
#  'test_folder/test_images/8945e4629.jpg',
#  'test_folder/test_images/247b453da.jpg',
#  'test_folder/test_images/7c041d03b.jpg',
#  'test_folder/test_images/c86ec1c09.jpg',
#  'test_folder/test_images/a1e018b01.jpg',
#  'test_folder/test_images/dd3276c10.jpg',
#  'test_folder/test_images/0a1785dc6.jpg',
#  'test_folder/test_images/a7e466ba3.jpg',
#  'test_folder/test_images/50b7531f2.jpg',
#  'test_folder/test_images/37c5bb9d8.jpg',
#  'test_folder/test_images/317181820.jpg',
#  'test_folder/test_images/02fa44546.jpg',
#  'test_folder/test_images/61f45212e.jpg',
#  'test_folder/test_images/8772b8fdc.jpg',
#  'test_folder/test_images/48344693a.jpg',
#  'test_folder/test_images/5fb33057d.jpg',
#  'test_folder/test_images/f5a7984a7.jpg',
#  'test_folder/test_images/f062bdc81.jpg',
#  'test_folder/test_images/7f17d70aa.jpg',
#  'test_folder/test_images/12aa665b5.jpg',
#  'test_folder/test_images/0e106a661.jpg',
#  'test_folder/test_images/fb18521d2.jpg',
#  'test_folder/test_images/bb4167184.jpg',
#  'test_folder/test_images/8890736be.jpg',
#  'test_folder/test_images/150760947.jpg',
#  'test_folder/test_images/03376858d.jpg',
#  'test_folder/test_images/48729d453.jpg',
#  'test_folder/test_images/afd3c6a62.jpg',
#  'test_folder/test_images/aa92ada1b.jpg',
#  'test_folder/test_images/2aa552150.jpg',
#  'test_folder/test_images/0aa099dec.jpg',
#  'test_folder/test_images/b96ac14e1.jpg',
#  'test_folder/test_images/9ecb8b3a9.jpg',
#  'test_folder/test_images/46c0cf150.jpg',
#  'test_folder/test_images/a95172d61.jpg',
#  'test_folder/test_images/012dbdb59.jpg',
#  'test_folder/test_images/8f855870b.jpg',
#  'test_folder/test_images/3843c2b42.jpg',
#  'test_folder/test_images/1581c707f.jpg',
#  'test_folder/test_images/e9cd25335.jpg',
#  'test_folder/test_images/c2a00a179.jpg',
#  'test_folder/test_images/0d972ff80.jpg',
#  'test_folder/test_images/14396afec.jpg',
#  'test_folder/test_images/21a7ccc17.jpg',
#  'test_folder/test_images/5589db9d2.jpg',
#  'test_folder/test_images/bf9571612.jpg',
#  'test_folder/test_images/642229b76.jpg',
#  'test_folder/test_images/c2babd6be.jpg',
#  'test_folder/test_images/de6156d89.jpg',
#  'test_folder/test_images/8d10b98c1.jpg',
#  'test_folder/test_images/0c949b8f3.jpg',
#  'test_folder/test_images/5c89043e5.jpg',
#  'test_folder/test_images/9870ab3ad.jpg',
#  'test_folder/test_images/a86686030.jpg',
#  'test_folder/test_images/034dc700c.jpg',
#  'test_folder/test_images/460dc85f3.jpg',
#  'test_folder/test_images/62bc77637.jpg',
#  'test_folder/test_images/59943b30b.jpg',
#  'test_folder/test_images/c2d8bec9e.jpg',
#  'test_folder/test_images/1375b451c.jpg',
#  'test_folder/test_images/613ec1955.jpg',
#  'test_folder/test_images/8a63e77b5.jpg',
#  'test_folder/test_images/2cb21412f.jpg',
#  'test_folder/test_images/a271faba9.jpg',
#  'test_folder/test_images/cbeacbd50.jpg',
#  'test_folder/test_images/8f1cd04dd.jpg',
#  'test_folder/test_images/172d31128.jpg',
#  'test_folder/test_images/3a8adfec1.jpg',
#  'test_folder/test_images/0219364ca.jpg',
#  'test_folder/test_images/af32a1daf.jpg',
#  'test_folder/test_images/1e49b9fe5.jpg',
#  'test_folder/test_images/a3cd1ebfa.jpg',
#  'test_folder/test_images/ce98c8298.jpg',
#  'test_folder/test_images/7f23e3ba7.jpg',
#  'test_folder/test_images/618716185.jpg',
#  'test_folder/test_images/004344e9f.jpg',
#  'test_folder/test_images/d5e45af27.jpg',
#  'test_folder/test_images/44450604e.jpg',
#  'test_folder/test_images/06b9c4981.jpg',
#  'test_folder/test_images/f0e46c993.jpg',
#  'test_folder/test_images/6bcd9173c.jpg',
#  'test_folder/test_images/f8c1fc67f.jpg',
#  'test_folder/test_images/eee921bdf.jpg',
#  'test_folder/test_images/19b5e6247.jpg',
#  'test_folder/test_images/569750ce6.jpg',
#  'test_folder/test_images/b6d928250.jpg',
#  'test_folder/test_images/caa41c242.jpg',
#  'test_folder/test_images/76aa0e052.jpg',
#  'test_folder/test_images/11ab6d4aa.jpg',
#  'test_folder/test_images/0277b3be9.jpg',
#  'test_folder/test_images/6870b3e34.jpg',
#  'test_folder/test_images/4e7b8030d.jpg',
#  'test_folder/test_images/5aef450e4.jpg',
#  'test_folder/test_images/e00620fc3.jpg',
#  'test_folder/test_images/1ac218498.jpg',
#  'test_folder/test_images/5b7133808.jpg',
#  'test_folder/test_images/a32b36ea2.jpg',
#  'test_folder/test_images/f030c1ffc.jpg',
#  'test_folder/test_images/34ab5d292.jpg',
#  'test_folder/test_images/8ac2a6e50.jpg',
#  'test_folder/test_images/17e02f282.jpg',
#  'test_folder/test_images/e5a324d37.jpg',
#  'test_folder/test_images/de4e11619.jpg',
#  'test_folder/test_images/c35fda653.jpg',
#  'test_folder/test_images/51dab6fe5.jpg',
#  'test_folder/test_images/670af3464.jpg',
#  'test_folder/test_images/93d000dc9.jpg',
#  'test_folder/test_images/9bbb966c6.jpg',
#  'test_folder/test_images/55bed5775.jpg',
#  'test_folder/test_images/5ba5f9552.jpg',
#  'test_folder/test_images/1b5dbd92b.jpg',
#  'test_folder/test_images/8d5ff7f81.jpg',
#  'test_folder/test_images/3a6a17330.jpg',
#  'test_folder/test_images/415955dff.jpg',
#  'test_folder/test_images/0bf02efd4.jpg',
#  'test_folder/test_images/d2322f862.jpg',
#  'test_folder/test_images/9507c5c71.jpg',
#  ...]

# %%
#Image size
sz = 100

# create generators
datagen=image.ImageDataGenerator(rescale=1./255, validation_split = 0.1)
test_datagen = image.ImageDataGenerator(rescale=1./255)

train_generator=datagen.flow_from_dataframe(
    dataframe=train_df, directory=img_path, 
    x_col="Image", y_col="Id", has_ext=True, seed = 42,
    class_mode="categorical", target_size=(sz,sz), batch_size=32, subset = "training")
#     class_mode="categorical", batch_size=32, subset = "training")

validation_generator = datagen.flow_from_dataframe(dataframe=train_df, directory=img_path, 
    x_col="Image", y_col="Id", has_ext=True, seed = 42,
    class_mode="categorical", target_size=(sz,sz), batch_size=32, subset = "validation")
test_generator = test_datagen.flow_from_directory(directory="test_folder", 
#       seed = 42, class_mode=None, batch_size=1, shuffle = False)                                            
    seed = 42, class_mode=None, target_size=(sz,sz), batch_size=1, shuffle = False)

STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=validation_generator.n//validation_generator.batch_size

# !ls test_folder/test_images | wc -l
# Out:
# Found 6677 images belonging to 633 classes.
# Found 721 images belonging to 633 classes.
# Found 7960 images belonging to 1 classes.
# 7960

# %%
#Training metrices
from keras.metrics import top_k_categorical_accuracy

''' the function top_5_accuracy is from Peter's kernel:
    https://www.kaggle.com/pestipeti/keras-cnn-starter
'''
def top_5_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=2)

  
chanDim = -1 # change this to 1 if you're using theano as a backend
#Create the model
  
model = Sequential()

# layer = Conv2D(filters = 32, 
#                kernel_size = 3, 
#                padding = 'same', 
#                activation = 'relu', 
#                input_shape = (100, 100, 3), 
#                kernel_regularizer=regularizers.l2(0.1))
layer = Conv2D(filters = 100, 
               kernel_size = 3, 
               padding = 'same', 
               activation = 'relu', 
               input_shape = (100, 100, 3)
              )

model.add(layer)
model.add(Dropout(0.2))

model.add(AveragePooling2D(pool_size=(3, 3)))

# %%
# Layer 3
# for i in range(10):
#   model.add(Conv2D(200, 
#                    (3, 3), 
#                    padding="same",
#                    activation = 'relu'))
#   model.add(BatchNormalization(axis=chanDim))
#   model.add(Dropout(0.5))

model.add(Conv2D(200, 
                 (3, 3), 
                 padding="same",
                 activation = 'relu'))
model.add(BatchNormalization(axis=chanDim))
model.add(Dropout(0.5))
  
model.add(AveragePooling2D(pool_size=(3, 3)))

# %%
# Layer 4
# for i in range(10):
#   model.add(Conv2D(400, 
#                    (3, 3), 
#                    padding="same",
#                    activation = 'relu'))
#   model.add(BatchNormalization(axis=chanDim))
#   model.add(Dropout(0.5))
  
model.add(Conv2D(400, 
                 (3, 3), 
                 padding="same",
                 activation = 'relu'))
model.add(BatchNormalization(axis=chanDim))
model.add(Dropout(0.5))  
  
model.add(AveragePooling2D(pool_size=(3, 3)))


# model.add(Conv2D(128, 
#                  (3, 3), 
#                  padding="same",
#                  kernel_regularizer=regularizers.l2(0.01),
#                  activity_regularizer=regularizers.l1(0.01)
#                 ))
# model.add(Activation("relu"))
# model.add(BatchNormalization(axis=chanDim))
# model.add(Dropout(0.25))
# model.add(AveragePooling2D(pool_size=(3, 3), input_shape=model.output_shape))

# %%
# Layer 5
# for i in range(10):
#   model.add(Conv2D(800, 
#                    (3, 3), 
#                    padding="same",
#                    activation = 'relu'))
#   model.add(BatchNormalization(axis=chanDim))
#   model.add(Dropout(0.9))

# model.add(Conv2D(800, 
#                  (3, 3), 
#                  padding="same",
#                  activation = 'relu'))
# model.add(BatchNormalization(axis=chanDim))
# model.add(Dropout(0.50))
  
# model.add(AveragePooling2D(pool_size=(3, 3)))

# model.add(Conv2D(256, 
#                  (3, 3), 
#                  padding="same",
#                  kernel_regularizer=regularizers.l2(0.01),
#                  activity_regularizer=regularizers.l1(0.01)
#                 ))
# model.add(Activation("relu"))
# model.add(BatchNormalization(axis=chanDim))
# model.add(Dropout(0.25))
# model.add(AveragePooling2D(pool_size=(2, 2), input_shape=model.output_shape))

# print(model.output_shape)

# %%
# model.add(GlobalAveragePooling2D())
# model.add(Flatten())

model.add(Dense(633, activation = 'softmax'))
# model.summary()

# %%
# model.add(Reshape((512, -1)))
# model.add(Permute((2, 1)))
# model.add(LSTM(32))

# model.add(LSTM(100,input_shape=(None,256)))

# %%
model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy', top_5_accuracy])

# early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
checkpointer = ModelCheckpoint(filepath='weights_larger1.hdf5', 
                               verbose=1, save_best_only=True)
checkpointer2 = ModelCheckpoint(filepath='weights_larger1_not_best.hdf5', 
                               verbose=1, save_best_only=False)

# early_stopping = EarlyStopping(monitor = 'val_loss', patience = 10)
early_stopping = EarlyStopping(monitor = 'val_top_5_accuracy', patience = 1000)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1627   try:
# -> 1628     c_op = c_api.TF_FinishOperation(op_desc)
#    1629   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Shape must be rank 2 but is rank 4 for 'metrics_4/top_5_accuracy/in_top_k/InTopKV2' (op: 'InTopKV2') with input shapes: [?,3,3,633], [?,?,?], [].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-6c84948d8757> in <module>()
#       1
#       2
# ----> 3 model.compile(optimizer= 'adam', loss='categorical_crossentropy', metrics=['accuracy', top_5_accuracy])
#       4
#       5 # early_stopping = EarlyStopping(monitor = 'val_loss', patience = 5)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in compile(self, optimizer, loss, metrics, loss_weights, sample_weight_mode, weighted_metrics, target_tensors, **kwargs)
#     449                 output_metrics = nested_metrics[i]
#     450                 output_weighted_metrics = nested_weighted_metrics[i]
# --> 451                 handle_metrics(output_metrics)
#     452                 handle_metrics(output_weighted_metrics, weights=weights)
#     453
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in handle_metrics(metrics, weights)
#     418                     metric_result = weighted_metric_fn(y_true, y_pred,
#     419                                                        weights=weights,
# --> 420                                                        mask=masks[i])
#     421
#     422                 # Append to self.metrics_names, self.metric_tensors,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py in weighted(y_true, y_pred, weights, mask)
#     402         """
#     403         # score_array has ndim >= 2
# --> 404         score_array = fn(y_true, y_pred)
#     405         if mask is not None:
#     406             # Cast the mask to floatX to avoid float64 upcasting in Theano
#
# <ipython-input-97-738aa37d4559> in top_5_accuracy(y_true, y_pred)
#       5 '''
#       6 def top_5_accuracy(y_true, y_pred):
# ----> 7     return top_k_categorical_accuracy(y_true, y_pred, k=2)
#       8
#       9
#
# /usr/local/lib/python3.6/dist-packages/keras/metrics.py in top_k_categorical_accuracy(y_true, y_pred, k)
#      42
#      43 def top_k_categorical_accuracy(y_true, y_pred, k=5):
# ---> 44     return K.mean(K.in_top_k(y_pred, K.argmax(y_true, axis=-1), k), axis=-1)
#      45
#      46
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in in_top_k(predictions, targets, k)
#    3472         values of `predictions[i]`.
#    3473     """
# -> 3474     return tf.nn.in_top_k(predictions, targets, k)
#    3475
#    3476
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_ops.py in in_top_k(predictions, targets, k, name)
#    2676   """
#    2677   with ops.name_scope(name, "in_top_k"):
# -> 2678     return gen_nn_ops.in_top_kv2(predictions, targets, k, name=name)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_nn_ops.py in in_top_kv2(predictions, targets, k, name)
#    4227   if _ctx is None or not _ctx._eager_context.is_eager:
#    4228     _, _, _op = _op_def_lib._apply_op_helper(
# -> 4229         "InTopKV2", predictions=predictions, targets=targets, k=k, name=name)
#    4230     _result = _op.outputs[:]
#    4231     _inputs_flat = _op.inputs
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     486                 'in a future version' if date is None else ('after %s' % date),
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     490                                        _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in create_op(***failed resolving arguments***)
#    3272           input_types=input_types,
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#    3276     return ret
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1790           op_def, inputs, node_def.attr)
#    1791       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1792                                 control_input_ops)
#    1793
#    1794     # Initialize self._outputs.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1629   except errors.InvalidArgumentError as e:
#    1630     # Convert to ValueError for backwards compatibility.
# -> 1631     raise ValueError(str(e))
#    1632
#    1633   return c_op
#
# ValueError: Shape must be rank 2 but is rank 4 for 'metrics_4/top_5_accuracy/in_top_k/InTopKV2' (op: 'InTopKV2') with input shapes: [?,3,3,633], [?,?,?], [].

# %%
# print(model.summary())
# model.load_weights('weights.hdf5')
# Train the model
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=validation_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=1000, callbacks = [checkpointer, early_stopping, checkpointer2])

# %%
#we need to use .reset() here otherwise
#the other of predictions will be different
#then the expected
test_generator.reset()
pred = model.predict_generator(test_generator,verbose = 1,steps=7960)

# %%
'''This filters only the top 5 possible ids of an image'''
pred_sorted = np.argsort(-pred, axis = 1)[:,:5]
pred_sorted

# %%
'''
Now we generate a map of each 
index to an Id on the format 
{
0: 'w_f48451c',
1: 'w_c3d896a',
2: 'w_20df2c5',
...
}
'''
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())

# %%
'''
Here we prepare pred_ids, which is a list of lists containing 
the top 5 ids by name. For example, w_13ae3d4. 
'''
from tqdm import tqdm
#create empty list
pred_ids = list()
for i,row in enumerate(tqdm(pred_sorted)):
    #create a temporary list to store the ids for a given image
    temp_list = []
    for j,value in enumerate(row):
        #for each index in pred_sorted, append the real Id in temp_list
        temp_list.append(labels[row[j]])
    #append all 5 ids for a given image to pred_ids
    #effectively creating a similar list to pred_sorted
    #but with the real ids
    pred_ids.append(temp_list)

# %%
'''create the final predictions by using all ids in a single string'''
final_preds = []
for i,top_5_ids in enumerate(pred_ids):
    final_preds.append(' '.join(pred_ids[i]))

# %%
'''delete the files on disk - otherwise the Kaggle kernel will throw an error'''
import shutil
shutil.rmtree('test_folder', ignore_errors=True)

# %%
# my_df_new = my_df[["c","a","b"]]

submission = pd.DataFrame({"Image": os.listdir('./test'), "Id": final_preds})
submission.to_csv("submission.csv", index = False, columns=["Image","Id"])
submission.head()

# !kaggle competitions submit -c humpback-whale-identification -f submission.csv -m "Message"
